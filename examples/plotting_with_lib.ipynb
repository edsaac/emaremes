# %%
import emaremes as mrms

# %%
file = mrms.download.LOCALPATH / "20210628/PrecipRate_00.00_20210628-000000.grib2"
assert file.exists()

# %%
fig = mrms.plot.plot_map(file, state="GA")

# %%
file = mrms.download.LOCALPATH / "20240927/PrecipRate_00.00_20240927-120000.grib2.gz"
assert file.exists()

# %%
fig = mrms.plot.plot_map(file, state="NC")

# %%
fig = mrms.plot.plot_map(file, state="CONUS")
