# %%
import emaremes as mrms

# %%
file = mrms.download.LOCALPATH / "20240927/PrecipRate_00.00_20240927-120000.grib2.gz"
assert file.exists()

# %%
fig = mrms.plot.precip_rate_map(file, state="NC")

# %%
fig = mrms.plot.precip_rate_map(file, state="CONUS")

# %%
file = mrms.download.LOCALPATH / "20240927/PrecipFlag_00.00_20240927-120000.grib2"
assert file.exists()

# %%
fig = mrms.plot.precip_flag_map(file, state="NC")

# %%
fig = mrms.plot.precip_flag_map(file, state="CONUS")
