# %%
from pathlib import Path
from emaremes.plot import plot_map

# %%
file = Path("../data_old/20210628/PrecipRate_00.00_20210628-000000.grib2")

# %%
fig = plot_map(file, state="ID")

# %%
fig = plot_map(file, state="CONUS")

# %%
fig = plot_map(file, state="WI")

# %%
fig = plot_map(file, state="MT")

# %%
fig = plot_map(file, state="FL")

# %%
fig = plot_map(file, state="WA")
